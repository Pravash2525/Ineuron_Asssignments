# %% [markdown]
# ### 1. What are the two values of the Boolean data type? How do you write them?
#
# > The two values of Boolean Data type are ___True___ & ___False___. <br>
# > we can write them by assigning to variable

# %% [markdown]
# ### 2. What are the three different types of Boolean operators?
#
# > __Boolean or Logical Operators__: "and", "or", "not"
# <table style= "border:1px solid black">
#   <thread>
#       <tr>
#         <th style= "border:1px solid black">Operator</th>
#         <th style= "border:1px solid black">Meaniing</th>
#         <th style= "border:1px solid black">Example</th>
#       </tr>
#   </thread>
#   <tbody>
#       <tr>
#         <td style= "border:1px solid black">and</td>
#         <td style= "border:1px solid black">True if both the operands are true</td>
#         <td style= "border:1px solid black">x and y</td>
#       </tr>
#       <tr>
#         <td style= "border:1px solid black">or</td>
#         <td style= "border:1px solid black">True if either of the operands is true</td>
#         <td style= "border:1px solid black">x or y</td>
#       </tr>
#       <tr>
#         <td style= "border:1px solid black">not</td>
#         <td style= "border:1px solid black">True if operand is false</td>
#         <td style= "border:1px solid black"> not x </td>
#       </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 3. Make a list of each Boolean operator's truth tables (i.e. every possible combination of Boolean values for the operator and what it evaluate ).
#
# > __Boolean Operator's Truth Tables__ <br>
#
# > 1. "and" Truth Table
#
# <table style= "border:1px solid black">
#   <thread>
#       <tr>
#         <th style= "border:1px solid black">x</th>
#         <th style= "border:1px solid black">y</th>
#         <th style= "border:1px solid black">x and y</th>
#       </tr>
#   </thread>
#   <tbody>
#       <tr>
#         <td style= "border:1px solid black">True</td>
#         <td style= "border:1px solid black">True</td>
#         <td style= "border:1px solid black">True</td>
#       </tr>
#       <tr>
#         <td style= "border:1px solid black">True</td>
#         <td style= "border:1px solid black">False</td>
#         <td style= "border:1px solid black">False</td>
#       </tr>
#       <tr>
#         <td style= "border:1px solid black">False</td>
#         <td style= "border:1px solid black">True</td>
#         <td style= "border:1px solid black">False</td>
#       </tr>
#       <tr>
#         <td style= "border:1px solid black">False</td>
#         <td style= "border:1px solid black">False</td>
#         <td style= "border:1px solid black">False</td>
#   </tbody>
# </table>
#
# > 2. "or" Truth Table
#
# <table style= "border:1px solid black">
#   <thread>
#       <tr>
#         <th style= "border:1px solid black">x</th>
#         <th style= "border:1px solid black">y</th>
#         <th style= "border:1px solid black">x and y</th>
#       </tr>
#   </thread>
#   <tbody>
#       <tr>
#         <td style= "border:1px solid black">True</td>
#         <td style= "border:1px solid black">True</td>
#         <td style= "border:1px solid black">True</td>
#       </tr>
#       <tr>
#         <td style= "border:1px solid black">True</td>
#         <td style= "border:1px solid black">False</td>
#         <td style= "border:1px solid black">True</td>
#       </tr>
#       <tr>
#         <td style= "border:1px solid black">False</td>
#         <td style= "border:1px solid black">True</td>
#         <td style= "border:1px solid black">True</td>
#       </tr>
#       <tr>
#         <td style= "border:1px solid black">False</td>
#         <td style= "border:1px solid black">False</td>
#         <td style= "border:1px solid black">False</td>
#   </tbody>
# </table>
#
# > 3. "not" Truth Table
#
# <table style= "border:1px solid black">
#   <thread>
#       <tr>
#         <th style= "border:1px solid black">x</th>
#         <th style= "border:1px solid black">not x</th>
#       </tr>
#   </thread>
#   <tbody>
#       <tr>
#         <td style= "border:1px solid black">True</td>
#         <td style= "border:1px solid black">False</td>
#       <tr>
#         <td style= "border:1px solid black">False</td>
#         <td style= "border:1px solid black">True</td>
#   </tbody>
# </table>

# %% [markdown]
# ### 4. What are the values of the following expressions?
#
# > * (5 > 4) and (3 == 5)  => False
# > * not (5 > 4) => False
# > * (5 > 4) or (3 == 5) => True
# > * not ((5 > 4) or (3 == 5)) => False
# > * (True and True) and (True == False) => False
# > * (not False) or (not True) => True

# %% [markdown]
# ### 5. What are the six comparison operators?
#
# > <ul>
#     <li> == Equal to </li>
#     <li> != 	Not equal to </li>
#     <li> < 	Less than </li>
#     <li> > 	Greater than </li>
#     <li> <= 	Less than or equal to </li>
#     <li> >= 	Greater than or equal to </li>
# </ul>

# %% [markdown]
# ### 6. How do you tell the difference between the equal to and assignment operators?Describe a condition and when you would use one.
#
# > + equal to operator used to check if two values are equal. And returns boolean value either True or False. <br>
# > + while assignment operator use to assign values to a variable
#
# > Example
# >```
# x = 5
# y = 7
# if x == y:
#     print("x is equal to y")
# else:
#     print("x is not equal to y")
# ```

# %% [markdown]
# ### 7. Identify the three blocks in this code:
#
# >```
# spam = 0
# if spam == 10:
#     print('eggs')
# if spam > 5:
#     print('bacon')
# else:
#     print('ham')
#     print('spam')
#     print('spam')
# ```

# %% [markdown]
# ### 8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints Greetings! if anything else is stored in spam.
#
# >```
# spam = 0
# if spam == 1:
#     print('Hello')
# elif spam > 2:
#     print('Howdy')
# else:
#     print('Greetings!')
# ```
